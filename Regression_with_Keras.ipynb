# %% [markdown]
# <a href="https://colab.research.google.com/github/jenniferoreffo/Keras-on-collab/blob/main/Regression_with_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy==1.21.6
# !pip install pandas==1.3.5
# !pip install keras==2.8.0
# !pip install matplotlib==3.5.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 11.2 MB 10.9 MB/s
# ...
#      |████████████████████████████████| 944 kB 70.2 MB/s
# ...
#      |████████████████████████████████| 42 kB 1.9 MB/s
# ...
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
# ...

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import np_utils

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# import the data
from google.colab import drive 
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
#file path
pd.read_csv('/content/gdrive/MyDrive/concrete_data (2).csv')
# Out:
#       Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0      540.0                 0.0      0.0  162.0               2.5
# 1      540.0                 0.0      0.0  162.0               2.5
# 2      332.5               142.5      0.0  228.0               0.0
# 3      332.5               142.5      0.0  228.0               0.0
# 4      198.6               132.4      0.0  192.0               0.0
# ...      ...                 ...      ...    ...               ...
# 1025   276.4               116.0     90.3  179.6               8.9
# 1026   322.2                 0.0    115.6  196.0              10.4
# 1027   148.5               139.4    108.6  192.7               6.1
# 1028   159.1               186.7      0.0  175.6              11.3
# 1029   260.9               100.5     78.3  200.6               8.6
#
#       Coarse Aggregate  Fine Aggregate  Age  Strength
# 0               1040.0           676.0   28     79.99
# ...

# %%
df = pd.read_csv('/content/gdrive/MyDrive/concrete_data (2).csv')
df.shape
# Out:
# (1030, 9)

# %%
df.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
df.describe()
df.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %%
#splitting the data
df_columns = df.columns

predictors = df[df_columns[df_columns != 'Strength']] # all columns except Strength
target = df['Strength'] # Strength column

# %%
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
target.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %%
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %%
n_cols = predictors_norm.shape[1] # number of predictors

# %%
#define regression model
def regression_model():
    # create model
    model = Sequential()
    model.add(Dense(10, activation='relu', input_shape=(n_cols,)))
    model.add(Dense(10, activation='relu'))
    model.add(Dense(1))
    
    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(predictors, target, test_size=0.3, random_state=42) 

# Build the model
model = regression_model()

# %%
# fit the model
epochs = 50
model.fit(x_train, y_train, epochs=epochs, verbose=1)
# Out:
# Epoch 1/50
# 23/23 [==============================] - 0s 2ms/step - loss: 6705.1484
# Epoch 2/50
# 23/23 [==============================] - 0s 2ms/step - loss: 1636.9015
# Epoch 3/50
# 23/23 [==============================] - 0s 2ms/step - loss: 1103.9999
# Epoch 4/50
# 23/23 [==============================] - 0s 2ms/step - loss: 923.3724
# Epoch 5/50
# 23/23 [==============================] - 0s 2ms/step - loss: 803.2844
# Epoch 6/50
# 23/23 [==============================] - 0s 2ms/step - loss: 701.4357
# Epoch 7/50
# 23/23 [==============================] - 0s 2ms/step - loss: 619.5500
# Epoch 8/50
# 23/23 [==============================] - 0s 2ms/step - loss: 556.8348
# Epoch 9/50
# 23/23 [==============================] - 0s 2ms/step - loss: 499.0527
# Epoch 10/50
# 23/23 [==============================] - 0s 2ms/step - loss: 455.3702
# Epoch 11/50
# 23/23 [==============================] - 0s 2ms/step - loss: 420.6133
# Epoch 12/50
# ...

# %%
loss_val = model.evaluate(x_test, y_test)
y_pred = model.predict(x_test)
loss_val
# Out:
# 10/10 [==============================] - 0s 2ms/step - loss: 193.0068
# 193.0067901611328

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error = mean_squared_error(y_test, y_pred)
mean = np.mean(mean_squared_error)
standard_deviation = np.std(mean_squared_error)
print(mean, standard_deviation)
# Out:
# 193.00677600509798 0.0

# %%
total_mean_squared_errors = 50
epochs = 50
mean_standard_error = []
for i in range(0, total_mean_squared_errors):
    x_train, x_test, y_train, = train_test_split(predictors, target, test_size=0.3, random_state=1)
    model.fit(x_train, y_train, epochs=epochs, verbose=0)
    MSE = model.evaluate(x_test, y_test, verbose=0)
    print("MSE" + str(i+1)+":" +str(MSE))
    y_pred = model.predict(x_test)
    mean_squared_error = mean_squared_error(y_test, y_pred)
    mean_squared_errors.append(mean_squared_error)

mean_squared_errors = np.array(mean_squared_errors)
mean = np.mean(mean_squared_errors)
standard_deviation = np.std(mean_squared_errors)

print("\n")
print("standard Deviation: "+str(standard_deviation))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-b086c0343566> in <module>()
#       3 mean_standard_error = []
#       4 for i in range(0, total_mean_squared_errors):
# ----> 5     x_train, x_test, y_train, = train_test_split(predictors, target, test_size=0.3, random_state=1)
#       6     model.fit(x_train, y_train, epochs=epochs, verbose=0)
#       7     MSE = model.evaluate(x_test, y_test, verbose=0)
#
# ValueError: too many values to unpack (expected 3)
